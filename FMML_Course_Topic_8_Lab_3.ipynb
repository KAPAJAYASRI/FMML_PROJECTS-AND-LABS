# %% [markdown]
# <a href="https://colab.research.google.com/github/KAPAJAYASRI/FMML_PROJECTS-AND-LABS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 09:53:11--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   106MB/s    in 0.6s
#
# 2024-03-26 09:53:12 (106 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22358  1603.05060v1  Linear autoregressive models serve as basic re...  stat
# 18021  cs/0112015v1  Much work in computer science has adopted comp...    cs
# 33815  1706.03170v1  Spiking neural networks (SNNs) enable power-ef...    cs
# 1235   1605.06402v1  Convolutional neural networks (CNN) have achie...    cs
# 40868  1503.06384v1  Declarative large-scale machine learning (ML) ...    cs
# ...             ...                                                ...   ...
# 3884   1504.06785v3  We consider the problem of recovering a comple...    cs
# 12481  1802.05046v2  Causal inference analysis is the estimation of...  stat
# 9011   1702.00564v2  We present a case-study demonstrating the usef...  stat
# 21839   1305.4152v5  Spatio-temporal point process models play a ce...  stat
# 12108  1708.06899v2  Biomonitoring of waterbodies is vital as the n...  stat
#
#                                                    title  year  \
# 22358  Short-term time series prediction using Hilber...  2016
# 18021                      Rational Competitive Analysis  2001
# 33815  Bio-Inspired Multi-Layer Spiking Neural Networ...  2017
# 1235   Ristretto: Hardware-Oriented Approximation of ...  2016
# 40868  Costing Generated Runtime Execution Plans for ...  2015
# ...                                                  ...   ...
# 3884        Complete Dictionary Recovery over the Sphere  2015
# 12481  Benchmarking Framework for Performance-Evaluat...  2018
# 9011   Modelling dependency completion in sentence co...  2017
# 21839  Sparse Approximate Inference for Spatio-Tempor...  2013
# 12108     Human experts vs. machines in taxa recognition  2017
#
#                                                 keywords
# 22358  [autoregressive, representations, stochastic, ...
# 18021  [competitive, uncertainty, competitive, classi...
# 33815  [efficient, implementations, unsupervised, dis...
# 1235   [convolutional, breakthroughs, performance, su...
# 40868  [declarative, specification, algorithms, autom...
# ...                                                  ...
# 3884   [recovering, sufficiently, theoretical, unders...
# 12481  [inference, estimation, healthcare, estimating...
# 9011   [demonstrating, usefulness, hierarchical, mode...
# 21839  [spatially, distributed, disciplines, inferenc...
# 12108  [biomonitoring, waterbodies, anthropogenic, st...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22358    [autoregressive, representations, stochastic, ...
# 18021    [competitive, uncertainty, competitive, classi...
# 33815    [efficient, implementations, unsupervised, dis...
# 1235     [convolutional, breakthroughs, performance, su...
# 40868    [declarative, specification, algorithms, autom...
#                                ...
# 13171    [computing, dimensional, increasingly, operati...
# 21787    [neuroscience, understand, responses, combinat...
# 35145    [axiomatizations, exponential, procedures, rea...
# 36228    [stackelberg, associated, computational, deplo...
# 2190     [reinforcement, iteration, similarity, paramet...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8873 words.
# Out of those 4569 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="226eb34d-8453-4c3e-a70c-2c727ac871a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("226eb34d-8453-4c3e-a70c-2c727ac871a2")) {                    Plotly.newPlot(                        "226eb34d-8453-4c3e-a70c-2c727ac871a2",                        [{"x":["framework","increased","different","distributions","embeddings","stochastic","methodology","including","motivated","representations","autoregressive","forecasting","prediction","embedding","processes","performance","definition","introduce","uncertainty","constraints","environment","competitive","rationality","application","classical","arbitrary","extraction","represents","subsequently","architecture","classifier","plasticity","integrate","dependent","recognition","discovery","favorably","implementations","demonstration","statistical","convolutional","unsupervised","probabilistic","discriminative","efficient","experimental","connected","acquisition","dedicated","consuming","alternatively","breakthroughs","compression","connection","guaranteed","computation","optimized","consumption","execution","squeezenet","significantly","multipliers","smartphones","altogether","accelerators","successfully","surpassed","monitoring","classification","approximation","available","resulting","capabilities","inference","applications","parameters","automated","operations","astonishing","accelerator","requirements","computational","arithmetic","tolerance","multiplication","simulates","important","computations","fundamental","optimization","evaluating","foundations","algorithms","leveraged","linearize","technique","structures","declarative","generating","alternative","generated","mapreduce","opportunities","generation","distributed","frameworks","successive","decisions","precondition","specification","optimizers","automatic","automatically","compilation","techniques","accumulation","experiments","extensive","performing","qualitatively","artifacts","introduced","processing","independently","resolution","producing","restoration","demosaicing","exacerbates","extensively","limitations","photography","separately","artificial","mathematically","principles","considers","achieving","addressing","perspective","challenges","intelligence","designing","corresponding","specified","functions","measuring","estimation","appropriate","functional","differential","sensitivity","releasing","specifically","established","preserving","summaries","privately","reproducing","dimensional","parameterized","recurrent","adversarial","differentiable","distribution","generative","continuous","sequences","multinomial","approaches","potential","maintaining","efficiency","reconstruct","segmentation","preliminary","satisfactory","developed","increases","reconstructed","expectation","arguments","perturbation","intriguing","reference","understood","properties","dimensions","published","arbitrarily","manifolds","landscapes","investigate","mathematical","perturbations","improvements","hypothesis","presented","topological","eliminated"],"y":[525,40,746,107,99,130,69,260,48,224,5,12,204,103,98,884,41,333,76,139,126,132,3,246,102,82,132,44,30,247,141,9,52,67,353,53,24,34,7,169,392,146,146,97,410,370,63,55,21,26,6,5,41,44,38,149,47,20,44,2,260,15,10,1,3,87,3,39,508,122,309,127,51,198,445,222,91,63,3,4,57,294,9,6,10,5,326,39,83,328,67,16,578,10,3,270,139,16,94,103,167,7,14,147,96,33,3,51,2,24,7,181,172,9,357,7,581,174,87,19,24,136,308,36,116,24,21,2,3,35,63,2,33,134,17,40,48,81,24,65,115,101,47,134,32,197,32,204,77,50,35,35,2,153,59,54,14,0,12,197,14,147,115,22,197,115,102,92,4,424,140,38,141,36,205,40,16,181,42,32,23,22,10,6,53,32,258,47,43,17,18,4,145,51,11,128,42,194,20,6],"type":"bar"},{"x":["framework","increased","different","di ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4569,), (4569, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8125

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>Discriminatively</span> <span style=''>Boosted</span> <span style=''>Image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>with</span> <span style=''>Fully</span> <span style='background-color:rgba(0, 255, 0, 0.6505263157894737);'>Convolutional</span> <span style=''>Auto</span> <span style=''>Encoders</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.32592592592592595);'>Traditional</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>methods</span> <span style=''>take</span> <span style=''>a</span> <span style=''>two</span> <span style=''>step</span> <span style=''>approach</span> <span style=''>feature</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequentially</span> <span style=''>However</span> <span style=''>recent</span> <span style=''>research</span> <span style=''>results</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combining</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separated</span> <span style=''>phases</span> <span style=''>in</span> <span style=''>a</span> <span style=''>unified</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>and</span> <span style=''>training</span> <span style=''>them</span> <span style=''>jointly</span> <span style=''>can</span> <span style=''>achieve</span> <span style=''>a</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.6505263157894737);'>convolutional</span> <span style=''>auto</span> <span style=''>encoders</span> <span style=''>for</span> <span style=''>image</span> <span style=''>feature</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>then</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>unified</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3413173652694611);'>representations</span> <span style=''>and</span> <span style=''>cluster</span> <span style=''>centers</span> <span style=''>jointly</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.6505263157894737);'>convolutional</span> <span style=''>auto</span> <span style=''>encoder</span> <span style=''>and</span> <span style=''>soft</span> <span style=''>k</span> <span style=''>means</span> <span style=''>scores</span> <span style=''>At</span> <span style=''>initial</span> <span style=''>stages</span> <span style=''>of</span> <span style=''>the</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3413173652694611);'>representations</span> <span style='background-color:rgba(0, 255, 0, 0.6639999999999999);'>extracted</span> <span style=''>from</span> <span style=''>the</span> <span style=''>auto</span> <span style=''>encoder</span> <span style=''>may</span> <span style=''>not</span> <span style=''>be</span> <span style=''>very</span> <span style='background-color ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Improved</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Augmented</span> <span style=''>k</span> <span style=''>means</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Identifying</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>homogeneous</span> <span style=''>clusters</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>heterogeneous</span> <span style=''>dataset</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>classes</span> <span style=''>of</span> <span style=''>problems</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>modeling</span> <span style=''>In</span> <span style=''>the</span> <span style=''>realm</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>partitional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>k</span> <span style=''>means</span> <span style=''>is</span> <span style=''>a</span> <span style=''>very</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>this</span> <span style=''>In</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technical</span> <span style=''>report</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>new</span> <span style=''>k</span> <span style=''>means</span> <span style=''>variant</span> <span style=''>called</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Augmented</span> <span style=''>k</span> <span style=''>means</span> <span style=''>which</span> <span style=''>is</span> <span style=''>a</span> <span style=''>hybrid</span> <span style=''>of</span> <span style=''>k</span> <span style=''>means</span> <span style=''>and</span> <span style=''>logistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>During</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteration</span> <span style=''>logistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>the</span> <span style=''>current</span> <span style=''>cluster</span> <span style=''>labels</span> <span style=''>and</span> <span style=''>the</span> <span style=''>cluster</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>belonging</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>are</span> <span style=''>used</span> <span style=''>to</span> <span style=''>control</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subsequent</span> <span style=''>re</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>cluster</span> <span style=''>means</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Observations</span> <span style=''>which</span> <span style=''>cant</span> <span style=''>be</span> <span style=''>firmly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identified</span> <span style=''>into</span> <span style=''>clusters</span> <span style=''>are</span> <span style=''>excluded</span> <span style=''>from</span> <span style=''>the</span> <span style=''>re</span> <span style='b ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style=''>Sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Complexity</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Graphical</span> <span style=''>Model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Selection</span> <span style=''>for</span> <span style=''>Non</span> <span style='background-color:rgba(255, 0, 0, 0.6052631578947367);'>Stationary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processes</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style=''>and</span> <span style=''>analyze</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inferring</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.358974358974359);'>independence</span> <span style=''>graph</span> <span style=''>of</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.30633802816901406);'>dimensional</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.6052631578947367);'>stationary</span> <span style=''>Gaussian</span> <span style=''>random</span> <span style=''>process</span> <span style=''>(time</span> <span style=''>series)</span> <span style=''>from</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>length</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observation</span> <span style=''>The</span> <span style=''>observed</span> <span style=''>process</span> <span style=''>samples</span> <span style=''>are</span> <span style=''>assumed</span> <span style='background-color:rgba(255, 0, 0, 0.5999999999999999);'>uncorrelated</span> <span style=''>over</span> <span style=''>time</span> <span style=''>but</span> <span style=''>having</span> <span style='background-color:rgba(0, 255, 0, 0.325044404973357);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.5892857142857143);'>covariance</span> <span style=''>matrices</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterize</span> <span style=''>the</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>for</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analyzing</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>method</span> <span style=''>which</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neighborhood</span> <span style='background-color:rgba(255, 0, 0, 0.5612903225806452);'>regression</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>indicate</span> <span style=''>similar</span> <span style=''>to</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style=''>iid</span> <span style=''>samples</span> <span style=''>accurate</span> <span style=''>GMS</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>even</span> <span style=''>in</span> <span style=''>th ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>examples</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>models</span> <br/><br/><span style=''>We</span> <span style=''>explore</span> <span style=''>methods</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>producing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>examples</span> <span style=''>on</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>models</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>autoencoder</span> <span style=''>(VAE)</span> <span style=''>and</span> <span style=''>the</span> <span style=''>VAE</span> <span style=''>GAN</span> <span style=''>Deep</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>are</span> <span style=''>known</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>vulnerable</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>examples</span> <span style=''>but</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>has</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>examples</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>tasks</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>models</span> <span style=''>have</span> <span style=''>recently</span> <span style=''>become</span> <span style=''>popular</span> <span style=''>due</span> <span style=''>to</span> <span style=''>their</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>model</span> <span style=''>input</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>and</span> <span style=''>generate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>realistic</span> <span style=''>examples</span> <span style=''>from</span> <span style=''>those</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>We</span> <span style=''>present</span> <span style=''>three</span> <span style=''>classes</span> <span style=''>of</span> <span style=''>attacks</span> <span style=''>on</span> <span style=''>the</span> <span style=''>VAE</span> <span style=''>and</span> <span style=''>VAE</span> <span style=''>GAN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>them</span> <span style=''>against</span> <span style=''>networks</span> <span style=''>trained</span> <span style=''>on</span> <span style=''>MNIST</span> <span style=''>SVHN</span> <span style=''>and</span> <span style=''>CelebA</span> <span style=''>Our</span> <span style=''>first</span> <span style=''>attack</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leverages</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversaries</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attaching</span> <span style=''>a</span> < ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09939437121482009)
# 	architecture (0.08799429996437477)
# 	representation (0.13359458496615603)
# 	information (0.24652654079087993)
# 	segmentation (0.0730317064481653)
# 	knowledge (0.13323833273957963)
# 	detection (0.12682579266120414)
# 	different (0.2657641610260064)
# 	recognition (0.1257570359814749)
# 	convolutional (0.1396508728179551)
#
# Some Statistics words are:
# 	stochastic (0.13095835423983943)
# 	statistical (0.15654791771199197)
# 	variables (0.14550928248871048)
# 	estimation (0.17661816357250376)
# 	theoretical (0.15002508780732565)
# 	algorithm (0.4049172102358254)
# 	distribution (0.1806322127446061)
# 	dimensional (0.18615153035624687)
# 	inference (0.19869543401906672)
# 	regression (0.1821374811841445)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d5685500-c91b-4b3b-8ea6-da65714cf4cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5685500-c91b-4b3b-8ea6-da65714cf4cd")) {                    Plotly.newPlot(                        "d5685500-c91b-4b3b-8ea6-da65714cf4cd",                        [{"x":["framework","increased","different","distributions","embeddings","stochastic","methodology","including","motivated","representations","autoregressive","forecasting","prediction","embedding","processes","performance","definition","introduce","uncertainty","constraints","environment","competitive","rationality","application","classical","arbitrary","extraction","represents","subsequently","architecture","classifier","plasticity","integrate","dependent","recognition","discovery","favorably","implementations","demonstration","statistical","convolutional","unsupervised","probabilistic","discriminative","efficient","experimental","connected","acquisition","dedicated","consuming","alternatively","breakthroughs","compression","connection","guaranteed","computation","optimized","consumption","execution","squeezenet","significantly","multipliers","smartphones","altogether","accelerators","successfully","surpassed","monitoring","classification","approximation","available","resulting","capabilities","inference","applications","parameters","automated","operations","astonishing","accelerator","requirements","computational","arithmetic","tolerance","multiplication","simulates","important","computations","fundamental","optimization","evaluating","foundations","algorithms","leveraged","linearize","technique","structures","declarative","generating","alternative","generated","mapreduce","opportunities","generation","distributed","frameworks","successive","decisions","precondition","specification","optimizers","automatic","automatically","compilation","techniques","accumulation","experiments","extensive","performing","qualitatively","artifacts","introduced","processing","independently","resolution","producing","restoration","demosaicing","exacerbates","extensively","limitations","photography","separately","artificial","mathematically","principles","considers","achieving","addressing","perspective","challenges","intelligence","designing","corresponding","specified","functions","measuring","estimation","appropriate","functional","differential","sensitivity","releasing","specifically","established","preserving","summaries","privately","reproducing","dimensional","parameterized","recurrent","adversarial","differentiable","distribution","generative","continuous","sequences","multinomial","approaches","potential","maintaining","efficiency","reconstruct","segmentation","preliminary","satisfactory","developed","increases","reconstructed","expectation","arguments","perturbation","intriguing","reference","understood","properties","dimensions","published","arbitrarily","manifolds","landscapes","investigate","mathematical","perturbations","improvements","hypothesis","presented","topological","eliminated","incorporating","goodfellow","kernelized","interpret","nonparametric","contamination","minimizer","sensitive","conditions","algorithm","associated","objective","robustness","detection","necessary","sufficient","efficiently","influence","iteratively","demonstrated","traditional","combining","estimator","representer","providing","guidelines","simplicity","information","development","obviously","underlying","developing","developers","complementary","multilingual","considerable","alleviate","resources","restrictive","dictionaries","feasibility","languages","principle","regarding","competitiveness","considered","challenging","worthwhile","spectrometry","characteristics","revealing","plausible","complexit ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	privately
# 	spectrometry
# 	methodologically
# 	commonplace
# 	coregionalization
# 	circumvents
# 	independences
# 	confounders
# 	dependences
# 	eliciting
# 	tailoring
# 	detectability
# 	majorizer
# 	orthogonality
# 	dissimilarities
# 	micrographs
# 	guideline
# 	dendrogram
# 	subdifferential
# 	uncoupled
# Some words which never appear in Statistics papers:
# 	plasticity
# 	breakthroughs
# 	accelerators
# 	surpassed
# 	accelerator
# 	linearize
# 	compilation
# 	demosaicing
# 	exacerbates
# 	photography
# 	visibility
# 	experimented
# 	syntactic
# 	phonological
# 	concisely
# 	distinctiveness
# 	listeners
# 	encryption
# 	allocated
# 	traveling

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0638193572106986e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7691666666666667
